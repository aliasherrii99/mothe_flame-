# %%
import numpy as np 
import pandas as pd
import random
import math
import time
from sklearn.metrics import confusion_matrix, accuracy_score  
import matplotlib.pyplot as plt  
import itertools 
from sklearn.model_selection import train_test_split

def normalize_to_0_1(dataset):

    mean_vals = np.mean(dataset, axis=0)
    std_vals = np.std(dataset, axis=0)
    
    standardized_data = (dataset - mean_vals) / std_vals
    
    return standardized_data  

def load_csv_data(file_path):
    
    data = pd.read_csv(file_path, header=None).to_numpy() 
    
    features = data[:, :-1]  
    labels = data[:, -1]  
    
    return features, labels.reshape(-1, 1)  

def encode_one_hot(labels):
    
    unique_labels, label_indices = np.unique(labels, return_inverse=True)  
    
    identity_matrix = np.eye(len(unique_labels))  
    
    one_hot_encoded = identity_matrix[label_indices] 
    
    return one_hot_encoded, unique_labels  


def visualize_confusion_matrix(true_labels, predicted_labels, class_names, plot_title, normalize=True, plot_size=(6,4), color_map=plt.cm.Blues):
    
    conf_matrix = confusion_matrix(np.argmax(true_labels, axis=1), np.argmax(predicted_labels, axis=1))  
    accuracy = accuracy_score(np.argmax(true_labels, axis=1), np.argmax(predicted_labels, axis=1))  
    
    if normalize:
        conf_matrix = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]  
        print("Normalized Confusion Matrix")  
    else:
        print('Confusion Matrix, without normalization')  
    
    width, height = plot_size  
    plt.figure(figsize=(width, height))  
    plt.imshow(conf_matrix, interpolation='nearest', cmap=color_map)  
    plt.title(f"{plot_title}\nAccuracy: {accuracy:.2f}")  
    plt.colorbar()  
    
    tick_marks = np.arange(len(class_names))  # ایجاد آرایه ای از شاخص های کلاس.
    plt.xticks(tick_marks, class_names, rotation=45)  # تنظیم نشانگرهای محور x با نام های کلاس ها به صورت چرخانده شده 45 درجه.
    plt.yticks(tick_marks, class_names)  # تنظیم نشانگرهای محور y با نام های کلاس ها.
    
    fmt = '.2f' if normalize else 'd'  # تنظیم قالب برای متن در سلول ها.
    threshold = conf_matrix.max() / 2.  # تعیین آستانه برای رنگ متن.
    
    for i, j in itertools.product(range(conf_matrix.shape[0]), range(conf_matrix.shape[1])):  # حلقه در ابعاد داده ها.
        plt.text(j, i, format(conf_matrix[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if conf_matrix[i, j] > threshold else "black")  # افزودن توضیحات متنی در سلول ها.
    
    plt.tight_layout()  # تنظیم طرح برای تناسب با عناصر.
    plt.ylabel('True label')  # تنظیم برچسب محور y.
    plt.xlabel('Predicted label')  # تنظیم برچسب محور x.
    plt.show()  # نمایش نمودار.

def plot_learning_curves(convergence_data):
    # تعریف تابع برای نمایش نمودارهای همگرایی.
    
    best_curve, mean_curve, worst_curve = convergence_data 
    plt.figure(figsize=(10, 4)) 
    
    plt.plot(best_curve[1:], color='green', label='Best') 
    plt.plot(mean_curve[1:], color='blue', label='Mean') 
    
    plt.title('Convergence Curves')
    plt.xlabel('Iteration')
    plt.ylabel('fitness')
    plt.legend()  
    plt.show() 

def sigmoid_function(x):

    return 1 / (1 + np.exp(-x))

class NeuralNetwork:
    def __init__(self, input_dim, hidden_units, output_units):

        self.input_dim = input_dim
        self.hidden_units = hidden_units
        self.output_units = output_units
        self.init_weights()  

    def init_weights(self):

        self.w1 = 2 * np.random.random((self.hidden_units, self.input_dim)) - 1  
        self.bias1 = np.zeros((self.hidden_units, 1))  
        self.w2 = 2 * np.random.random((self.output_units, self.hidden_units)) - 1  
        self.bias2 = np.zeros((self.output_units))  
        
        self.trainable_params = np.size(self.w1) + np.size(self.bias1) + np.size(self.w2) + np.size(self.bias2)

    def forward_pass(self, inputs):
        input_data = np.array(inputs, dtype='float32').reshape(-1, self.input_dim) 
        output_data = np.zeros((input_data.shape[0], self.output_units))  
        index = 0  
        for sample in input_data:  
            net_input_hidden = self.w1 @ sample.reshape(-1, 1) + self.bias1.reshape(-1, 1)  
            hidden_output = sigmoid_function(net_input_hidden)  
            net_input_output = self.w2 @ hidden_output.reshape(-1, 1) + self.bias2.reshape(-1, 1)  
            final_output = sigmoid_function(net_input_output)  
            output_data[index, :] = final_output.ravel()  
            index += 1  
        return output_data  

    def set_params_from_vector(self, params):
        parameter_vector = np.array(params, dtype='float32').ravel()  
        if np.size(parameter_vector) != self.trainable_params:
            raise ValueError('طول پارامترها برابر با تعداد پارامترهای قابل آموزش نیست') 
        index_1 = self.input_dim * self.hidden_units  
        self.w1 = parameter_vector[:index_1].reshape((self.hidden_units, self.input_dim))  
        index_2 = index_1 + self.hidden_units  
        self.bias1 = parameter_vector[index_1:index_2].reshape((self.hidden_units, 1))  
        index_3 = index_2 + self.output_units * self.hidden_units  
        self.w2 = parameter_vector[index_2:index_3].reshape((self.output_units, self.hidden_units))  
        self.bias2 = parameter_vector[index_3:].reshape((self.output_units))  

    def compute_mse(self, inputs, targets):
    
        predictions = self.forward_pass(inputs)  
        error = np.array(targets, dtype='float32') - predictions  
        return np.mean(error ** 2)  

def optimization_objective(params, inputs, targets, network):
    network.set_params_from_vector(params)  
    return network.compute_mse(inputs, targets)  

def objective_function(params, train_input, train_target, network):
    network.set_params_from_vector(params)  # Set the network parameters.
    return network.compute_mse(train_input, train_target)  # Return the MSE loss.

# %%
class OptimizationResult:
    def __init__(self):
        self.execution_time = None
        self.convergence_curve = None
        self.best_individual = None
        self.best_score = None

class OptimizationResult:
    def __init__(self):
        self.execution_time = None
        self.convergence_curve = None
        self.best_individual = None
        self.best_score = None

def MothFlameOptimizer(objective_function, dimensions, train_input, train_target,
                       neural_net_func, lower_bound=-1, upper_bound=1, num_moths=40, max_iterations=100, repeat=1):
    if not isinstance(lower_bound, list):
        lower_bound = [lower_bound] * dimensions
    if not isinstance(upper_bound, list):
        upper_bound = [upper_bound] * dimensions

    best_overall_score = float('inf')
    best_overall_position = None
    fitness_all_repeats = []

    start_time = time.time()
    
    for r in range(repeat):
        moth_positions = np.zeros((num_moths, dimensions))
        for i in range(dimensions):
            moth_positions[:, i] = np.random.uniform(0, 1, num_moths) * (upper_bound[i] - lower_bound[i]) + lower_bound[i]
        
        moth_fitness = np.full(num_moths, float("inf"))

        best_curve = np.zeros(max_iterations)
        worst_curve = best_curve.copy()
        mean_curve = best_curve.copy()

        sorted_population = np.copy(moth_positions)
        fitness_sorted = np.zeros(num_moths)

        best_flames = np.copy(moth_positions)
        best_flame_fitness = np.zeros(num_moths)

        double_population = np.zeros((2 * num_moths, dimensions))
        double_fitness = np.zeros(2 * num_moths)

        double_sorted_population = np.zeros((2 * num_moths, dimensions))
        double_fitness_sorted = np.zeros(2 * num_moths)

        previous_population = np.zeros((num_moths, dimensions))
        previous_fitness = np.zeros(num_moths)

        iteration = 1

        while iteration < max_iterations:
            flame_count = round(num_moths - iteration * ((num_moths - 1) / max_iterations))

            for i in range(num_moths):
                for j in range(dimensions):
                    moth_positions[i, j] = np.clip(moth_positions[i, j], lower_bound[j], upper_bound[j])
                moth_fitness[i] = objective_function(moth_positions[i, :], train_input, train_target, neural_net_func)

            if iteration == 1:
                fitness_sorted = np.sort(moth_fitness)
                sorted_indices = np.argsort(moth_fitness)
                sorted_population = moth_positions[sorted_indices, :]
                best_flames = sorted_population
                best_flame_fitness = fitness_sorted
            else:
                double_population = np.concatenate((previous_population, best_flames), axis=0)
                double_fitness = np.concatenate((previous_fitness, best_flame_fitness), axis=0)
                double_fitness_sorted = np.sort(double_fitness)
                sorted_indices_2 = np.argsort(double_fitness)

                for new_index in range(2 * num_moths):
                    double_sorted_population[new_index, :] = np.array(double_population[sorted_indices_2[new_index], :])

                fitness_sorted = double_fitness_sorted[:num_moths]
                sorted_population = double_sorted_population[:num_moths, :]
                best_flames = sorted_population
                best_flame_fitness = fitness_sorted

            best_flame_score = fitness_sorted[0]
            best_flame_position = sorted_population[0, :]
            previous_population = moth_positions
            previous_fitness = moth_fitness

            a = -1 + iteration * ((-1) / max_iterations)

            for i in range(num_moths):
                for j in range(dimensions):
                    if i <= flame_count:
                        distance_to_flame = abs(sorted_population[i, j] - moth_positions[i, j])
                        b = 1
                        t = (a - 1) * random.random() + 1
                        moth_positions[i, j] = (distance_to_flame * math.exp(b * t) * math.cos(t * 2 * math.pi)
                                                + sorted_population[i, j])
                    else:
                        distance_to_flame = abs(sorted_population[i, j] - moth_positions[i, j])
                        b = 1
                        t = (a - 1) * random.random() + 1
                        moth_positions[i, j] = (distance_to_flame * math.exp(b * t) * math.cos(t * 2 * math.pi)
                                                + sorted_population[flame_count, j])

            best_curve[iteration] = best_flame_score
            mean_curve[iteration] = np.mean(fitness_sorted)
            worst_curve[iteration] = fitness_sorted[-1]

            if iteration % 1 == 0:
                print(f"Repeat {r+1} - Iteration {iteration} / {max_iterations}     best fitness : {best_flame_score}")
                print('---------------------------------------')

            iteration += 1

        fitness_all_repeats.append(best_flame_score)

        if best_flame_score < best_overall_score:
            best_overall_score = best_flame_score
            best_overall_position = best_flame_position

    end_time = time.time()
    result = OptimizationResult()
    result.execution_time = end_time - start_time
    result.convergence_curve = (best_curve, mean_curve, worst_curve)
    result.best_individual = best_overall_position
    result.best_score = best_overall_score

    fitness_mean = np.mean(fitness_all_repeats)
    fitness_std = np.std(fitness_all_repeats)
    print(f"Mean fitness over all repeats: {fitness_mean}")
    print(f"Standard deviation of fitness over all repeats: {fitness_std}")

    return result

# %%
n_input_iris, n_hidden_iris, n_output_iris = 4, 9, 3  # Define the network architecture: 4 inputs, 9 hidden neurons, 3 outputs.
iris_classifier = NeuralNetwork(n_input_iris, n_hidden_iris, n_output_iris)  # Initialize the MLP classifier for Iris dataset.

n_input_breast, n_hidden_breast, n_output_breast = 9, 19, 1  # Define the network architecture: 9 inputs, 19 hidden neurons, 1 output.
breast_classifier = NeuralNetwork(n_input_breast, n_hidden_breast, n_output_breast)  # Initialize the MLP classifier for Breast Cancer dataset.

# Read and preprocess the Iris dataset.
X_iris, Y_iris = load_csv_data('iris.csv')  # Read Iris dataset.
# X_iris = normalize_to_0_1(X_iris)  # Normalize features (commented out).
Y_iris, unique_iris = encode_one_hot(Y_iris)  # One-hot encode target labels.

# Read and preprocess the Breast Cancer dataset.
X_breast, Y_breast = load_csv_data('breast-cancer-wisconsin.csv')  # Read Breast Cancer dataset.
X_breast = normalize_to_0_1(X_breast)  # Normalize features.
unique_breasts = np.unique(Y_breast)  # Get unique target labels.
Y_breast = np.where(Y_breast == unique_breasts[0], 0, 1)  # Convert targets to binary labels.

# Split the datasets into training and testing sets.
train_X_iris, test_X_iris, train_Y_iris, test_Y_iris = train_test_split(X_iris, Y_iris, test_size=0.2, shuffle=True)  # Split Iris dataset.
train_X_breast, test_X_breast, train_Y_breast, test_Y_breast = train_test_split(X_breast, Y_breast, test_size=0.2, shuffle=True)  # Split Breast Cancer dataset.

# %% [markdown]
# # Iris

# %%
# Train the MLP classifier for Iris dataset using MFO optimizer.
results_iris = MothFlameOptimizer(objective_function=objective_function, dimensions=iris_classifier.trainable_params, 
                                  train_input=train_X_iris, train_target=train_Y_iris, 
                                  neural_net_func=iris_classifier, num_moths=30, max_iterations=150 , repeat = 5)  # Run MFO optimization.
# Out:
# Repeat 1 - Iteration 1 / 150     best fitness : 0.22101732249327416
# ---------------------------------------
# Repeat 1 - Iteration 2 / 150     best fitness : 0.22101732249327416
# ---------------------------------------
# Repeat 1 - Iteration 3 / 150     best fitness : 0.21658751889658384
# ---------------------------------------
# Repeat 1 - Iteration 4 / 150     best fitness : 0.206303236738339
# ---------------------------------------
# Repeat 1 - Iteration 5 / 150     best fitness : 0.19213200413102854
# ---------------------------------------
# Repeat 1 - Iteration 6 / 150     best fitness : 0.19213200413102854
# ---------------------------------------
# Repeat 1 - Iteration 7 / 150     best fitness : 0.19213200413102854
# ---------------------------------------
# Repeat 1 - Iteration 8 / 150     best fitness : 0.19213200413102854
# ---------------------------------------
# Repeat 1 - Iteration 9 / 150     best fitness : 0.19213200413102854
# ---------------------------------------
# Repeat 1 - Iteration 10 / 150     best fitness : 0.19213200413102854
# ---------------------------------------
# Repeat 1 - Iteration 11 / 150     best fitness : 0.19213200413102854
# ---------------------------------------
# Repeat 1 - Iteration 12 / 150     best fitness : 0.18800622502329414
# ---------------------------------------
# Repeat 1 - Iteration 13 / 150     best fitness : 0.18757372712761466
# ---------------------------------------
# Repeat 1 - Iteration 14 / 150     best fitness : 0.18757372712761466
# ---------------------------------------
# Repeat 1 - Iteration 15 / 150     best fitness : 0.18757372712761466
# ---------------------------------------
# Repeat 1 - Iteration 16 / 150     best fitness : 0.18658970842445172
# ---------------------------------------
# Repeat 1 - Iteration 17 / 150     best fitness : 0.1858547951908062
# ---------------------------------------
# Repeat 1 - Iteration 18 / 150     best fitness : 0.1858547951908062
# ---------------------------------------
# Repeat 1 - Iteration 19 / 150     best fitness : 0.1858547951908062
# ---------------------------------------
# Repeat 1 - Iteration 20 / 150     best fitness : 0.1792321805987197
# ---------------------------------------
# Repeat 1 - Iteration 21 / 150     best fitness : 0.1792321805987197
# ---------------------------------------
# Repeat 1 - Iteration 22 / 150     best fitness : 0.1653020848630425
# ---------------------------------------
# Repeat 1 - Iteration 23 / 150     best fitness : 0.1653020848630425
# ---------------------------------------
# Repeat 1 - Iteration 24 / 150     best fitness : 0.1653020848630425
# ---------------------------------------
# Repeat 1 - Iteration 25 / 150     best fitness : 0.164920384316935
# ---------------------------------------
# Repeat 1 - Iteration 26 / 150     best fitness : 0.164920384316935
# ---------------------------------------
# Repeat 1 - Iteration 27 / 150     best fitness : 0.164920384316935
# ---------------------------------------
# Repeat 1 - Iteration 28 / 150     best fitness : 0.164920384316935
# ---------------------------------------
# Repeat 1 - Iteration 29 / 150     best fitness : 0.1620505746990348
# ---------------------------------------
# Repeat 1 - Iteration 30 / 150     best fitness : 0.1620505746990348
# ---------------------------------------
# Repeat 1 - Iteration 31 / 150     best fitness : 0.1576831050068285
# ---------------------------------------
# Repeat 1 - Iteration 32 / 150     best fitness : 0.1576831050068285
# ---------------------------------------
# Repeat 1 - Iteration 33 / 150     best fitness : 0.15559460114545104
# ---------------------------------------
# Repeat 1 - Iteration 34 / 150     best fitness : 0.15559460114545104
# ---------------------------------------
# Repeat 1 - Iteration 35 / 150     best fitness : 0.15559460114545104
# ---------------------------------------
# Repeat 1 - Iteration 36 / 150     best fitness : 0.15244256997974442
# ---------------------------------------
# Repeat 1 - Iteration 37 / 150     best fitness : 0.15244256997974442
# ---------------------------------------
# Repeat 1 - Iteration 38 / 150     best fitness : 0.15237278632254955
# ---------------------------------------
# Repeat 1 - Iteration 39 / 150     best fitness : 0.15237278632254955
# ---------------------------------------
# Repeat 1 - Iteration 40 / 150     best fitness : 0.15237278632254955
# ---------------------------------------
# Repeat 1 - Iteration 41 / 150     best fitness : 0.14907879565551743
# ---------------------------------------
# Repeat 1 - Iteration 42 / 150     best fitness : 0.14907879565551743
# ---------------------------------------
# Repeat 1 - Iteration 43 / 150     best fitness : 0.14907879565551743
# ---------------------------------------
# Repeat 1 - Iteration 44 / 150     best fitness : 0.14907879565551743
# ---------------------------------------
# Repeat 1 - Iteration 45 / 150     best fitness : 0.14592897626526186
# ---------------------------------------
# Repeat 1 - Iteration 46 / 150     best fitness : 0.13584378549299625
# ---------------------------------------
# ---------------------------------------
# Repeat 1 - Iteration 149 / 150     best fitness : 0.09083540053159656
# ---------------------------------------
# Repeat 2 - Iteration 1 / 150     best fitness : 0.2259633233370194
# ---------------------------------------
# Repeat 2 - Iteration 2 / 150     best fitness : 0.2259633233370194
# ---------------------------------------
# Repeat 2 - Iteration 3 / 150     best fitness : 0.20937583417429936
# ---------------------------------------
# Repeat 2 - Iteration 4 / 150     best fitness : 0.2057558400486774
# ---------------------------------------
# Repeat 2 - Iteration 5 / 150     best fitness : 0.2057558400486774
# ---------------------------------------
# Repeat 2 - Iteration 6 / 150     best fitness : 0.2036701105192224
# ---------------------------------------
# Repeat 2 - Iteration 7 / 150     best fitness : 0.19349782537988855
# ---------------------------------------
# Repeat 2 - Iteration 8 / 150     best fitness : 0.19349782537988855
# ---------------------------------------
# Repeat 2 - Iteration 9 / 150     best fitness : 0.19349782537988855
# ---------------------------------------
# Repeat 2 - Iteration 10 / 150     best fitness : 0.19349782537988855
# ---------------------------------------
# Repeat 2 - Iteration 11 / 150     best fitness : 0.19349782537988855
# ---------------------------------------
# Repeat 2 - Iteration 12 / 150     best fitness : 0.19315772953642088
# ---------------------------------------
# Repeat 2 - Iteration 13 / 150     best fitness : 0.18600224397284842
# ---------------------------------------
# Repeat 2 - Iteration 14 / 150     best fitness : 0.17017037100526317
# ---------------------------------------
# Repeat 2 - Iteration 15 / 150     best fitness : 0.17017037100526317
# ---------------------------------------
# Repeat 2 - Iteration 16 / 150     best fitness : 0.17017037100526317
# ---------------------------------------
# Repeat 2 - Iteration 17 / 150     best fitness : 0.16611756922473944
# ---------------------------------------
# Repeat 2 - Iteration 18 / 150     best fitness : 0.16611756922473944
# ---------------------------------------
# Repeat 2 - Iteration 19 / 150     best fitness : 0.16476044750088845
# ---------------------------------------
# Repeat 2 - Iteration 20 / 150     best fitness : 0.16476044750088845
# ---------------------------------------
# Repeat 2 - Iteration 21 / 150     best fitness : 0.16476044750088845
# ---------------------------------------
# Repeat 2 - Iteration 22 / 150     best fitness : 0.1598466891245231
# ---------------------------------------
# Repeat 2 - Iteration 23 / 150     best fitness : 0.14558323550988905
# ---------------------------------------
# Repeat 2 - Iteration 24 / 150     best fitness : 0.14558323550988905
# ---------------------------------------
# Repeat 2 - Iteration 25 / 150     best fitness : 0.14343846873457972
# ---------------------------------------
# Repeat 2 - Iteration 26 / 150     best fitness : 0.14343846873457972
# ---------------------------------------
# Repeat 2 - Iteration 27 / 150     best fitness : 0.14343846873457972
# ---------------------------------------
# Repeat 2 - Iteration 28 / 150     best fitness : 0.14343846873457972
# ---------------------------------------
# Repeat 2 - Iteration 29 / 150     best fitness : 0.1395058768754981
# ---------------------------------------
# Repeat 2 - Iteration 30 / 150     best fitness : 0.1360060700165107
# ---------------------------------------
# Repeat 2 - Iteration 31 / 150     best fitness : 0.1360060700165107
# ---------------------------------------
# Repeat 2 - Iteration 32 / 150     best fitness : 0.134928129547005
# ---------------------------------------
# Repeat 2 - Iteration 33 / 150     best fitness : 0.12677179549827172
# ---------------------------------------
# Repeat 2 - Iteration 34 / 150     best fitness : 0.12677179549827172
# ---------------------------------------
# Repeat 2 - Iteration 35 / 150     best fitness : 0.12298358300785538
# ---------------------------------------
# Repeat 2 - Iteration 36 / 150     best fitness : 0.12298358300785538
# ---------------------------------------
# Repeat 2 - Iteration 37 / 150     best fitness : 0.1205551494777216
# ---------------------------------------
# Repeat 2 - Iteration 38 / 150     best fitness : 0.1176328861445215
# ---------------------------------------
# Repeat 2 - Iteration 39 / 150     best fitness : 0.1176328861445215
# ---------------------------------------
# Repeat 2 - Iteration 40 / 150     best fitness : 0.1176328861445215
# ---------------------------------------
# Repeat 2 - Iteration 41 / 150     best fitness : 0.11430593278097852
# ---------------------------------------
# Repeat 2 - Iteration 42 / 150     best fitness : 0.11430593278097852
# ---------------------------------------
# Repeat 2 - Iteration 43 / 150     best fitness : 0.11430593278097852
# ---------------------------------------
# Repeat 2 - Iteration 44 / 150     best fitness : 0.11378616609162759
# ---------------------------------------
# Repeat 2 - Iteration 45 / 150     best fitness : 0.11378616609162759
# ---------------------------------------
# Repeat 2 - Iteration 46 / 150     best fitness : 0.11378616609162759
# ---------------------------------------
# Repeat 2 - Iteration 47 / 150     best fitness : 0.11378616609162759
# ---------------------------------------
# Repeat 2 - Iteration 48 / 150     best fitness : 0.11094119234297399
# ---------------------------------------
# Repeat 2 - Iteration 49 / 150     best fitness : 0.10983284656742992
# ---------------------------------------
# Repeat 2 - Iteration 50 / 150     best fitness : 0.10983284656742992
# ---------------------------------------
# Repeat 2 - Iteration 51 / 150     best fitness : 0.10777588340494132
# ---------------------------------------
# Repeat 2 - Iteration 52 / 150     best fitness : 0.10777588340494132
# ---------------------------------------
# Repeat 2 - Iteration 53 / 150     best fitness : 0.10777588340494132
# ---------------------------------------
# Repeat 2 - Iteration 54 / 150     best fitness : 0.10777588340494132
# ---------------------------------------
# Repeat 2 - Iteration 55 / 150     best fitness : 0.10777588340494132
# ---------------------------------------
# Repeat 2 - Iteration 56 / 150     best fitness : 0.10777588340494132
# ---------------------------------------
# Repeat 2 - Iteration 57 / 150     best fitness : 0.10726271518198316
# ---------------------------------------
# Repeat 2 - Iteration 58 / 150     best fitness : 0.10726271518198316
# ---------------------------------------
# Repeat 2 - Iteration 59 / 150     best fitness : 0.10726271518198316
# ---------------------------------------
# Repeat 2 - Iteration 60 / 150     best fitness : 0.10523780985491318
# ---------------------------------------
# Repeat 2 - Iteration 61 / 150     best fitness : 0.10523780985491318
# ---------------------------------------
# Repeat 2 - Iteration 62 / 150     best fitness : 0.10523780985491318
# ---------------------------------------
# Repeat 2 - Iteration 63 / 150     best fitness : 0.10390553654255273
# ---------------------------------------
# Repeat 2 - Iteration 64 / 150     best fitness : 0.10390553654255273
# ---------------------------------------
# Repeat 2 - Iteration 65 / 150     best fitness : 0.1029568748016802
# ---------------------------------------
# Repeat 2 - Iteration 66 / 150     best fitness : 0.10090245107800401
# ---------------------------------------
# ---------------------------------------
# Repeat 2 - Iteration 101 / 150     best fitness : 0.09288520017644217
# ---------------------------------------
# Repeat 2 - Iteration 102 / 150     best fitness : 0.09274047422774216
# ---------------------------------------
# Repeat 2 - Iteration 103 / 150     best fitness : 0.09239693392699516
# ---------------------------------------
# Repeat 2 - Iteration 104 / 150     best fitness : 0.0922182302072479
# ---------------------------------------
# Repeat 2 - Iteration 105 / 150     best fitness : 0.0922182302072479
# ---------------------------------------
# Repeat 2 - Iteration 106 / 150     best fitness : 0.09189776838792149
# ---------------------------------------
# Repeat 2 - Iteration 107 / 150     best fitness : 0.09176064179422772
# ---------------------------------------
# Repeat 2 - Iteration 108 / 150     best fitness : 0.09176064179422772
# ---------------------------------------
# Repeat 2 - Iteration 109 / 150     best fitness : 0.0915223721383762
# ---------------------------------------
# Repeat 2 - Iteration 110 / 150     best fitness : 0.0915223721383762
# ---------------------------------------
# Repeat 2 - Iteration 111 / 150     best fitness : 0.09148868660276913
# ---------------------------------------
# Repeat 2 - Iteration 112 / 150     best fitness : 0.09148868660276913
# ---------------------------------------
# Repeat 2 - Iteration 113 / 150     best fitness : 0.09148868660276913
# ---------------------------------------
# Repeat 2 - Iteration 114 / 150     best fitness : 0.09136968369943982
# ---------------------------------------
# Repeat 2 - Iteration 115 / 150     best fitness : 0.09136968369943982
# ---------------------------------------
# Repeat 2 - Iteration 116 / 150     best fitness : 0.09111988298556284
# ---------------------------------------
# Repeat 2 - Iteration 117 / 150     best fitness : 0.09111988298556284
# ---------------------------------------
# Repeat 2 - Iteration 118 / 150     best fitness : 0.09107294319472019
# ---------------------------------------
# Repeat 2 - Iteration 119 / 150     best fitness : 0.09102483332709477
# ---------------------------------------
# Repeat 2 - Iteration 120 / 150     best fitness : 0.09102483332709477
# ---------------------------------------
# Repeat 2 - Iteration 121 / 150     best fitness : 0.09081577318389052
# ---------------------------------------
# Repeat 2 - Iteration 122 / 150     best fitness : 0.09081577318389052
# ---------------------------------------
# Repeat 2 - Iteration 123 / 150     best fitness : 0.09081577318389052
# ---------------------------------------
# Repeat 2 - Iteration 124 / 150     best fitness : 0.09070555798404663
# ---------------------------------------
# Repeat 2 - Iteration 125 / 150     best fitness : 0.09070555798404663
# ---------------------------------------
# Repeat 2 - Iteration 126 / 150     best fitness : 0.0905984462032713
# ---------------------------------------
# Repeat 2 - Iteration 127 / 150     best fitness : 0.0904873333313806
# ---------------------------------------
# Repeat 2 - Iteration 128 / 150     best fitness : 0.0904873333313806
# ---------------------------------------
# Repeat 2 - Iteration 129 / 150     best fitness : 0.09044245995721545
# ---------------------------------------
# Repeat 2 - Iteration 130 / 150     best fitness : 0.09033354030741303
# ---------------------------------------
# Repeat 2 - Iteration 131 / 150     best fitness : 0.09032964027840522
# ---------------------------------------
# Repeat 2 - Iteration 132 / 150     best fitness : 0.0898969005700893
# ---------------------------------------
# Repeat 2 - Iteration 133 / 150     best fitness : 0.0898969005700893
# ---------------------------------------
# Repeat 3 - Iteration 19 / 150     best fitness : 0.15261791408506764
# ---------------------------------------
# Repeat 3 - Iteration 20 / 150     best fitness : 0.15261791408506764
# ---------------------------------------
# Repeat 3 - Iteration 21 / 150     best fitness : 0.15261791408506764
# ---------------------------------------
# Repeat 3 - Iteration 22 / 150     best fitness : 0.15261791408506764
# ---------------------------------------
# Repeat 3 - Iteration 23 / 150     best fitness : 0.15142829801934282
# ---------------------------------------
# Repeat 3 - Iteration 24 / 150     best fitness : 0.15142829801934282
# ---------------------------------------
# Repeat 3 - Iteration 25 / 150     best fitness : 0.15142829801934282
# ---------------------------------------
# Repeat 3 - Iteration 26 / 150     best fitness : 0.15142829801934282
# ---------------------------------------
# Repeat 3 - Iteration 27 / 150     best fitness : 0.15142829801934282
# ---------------------------------------
# Repeat 3 - Iteration 28 / 150     best fitness : 0.15142829801934282
# ---------------------------------------
# Repeat 3 - Iteration 29 / 150     best fitness : 0.15037440610101538
# ---------------------------------------
# Repeat 3 - Iteration 30 / 150     best fitness : 0.148263403864447
# ---------------------------------------
# Repeat 3 - Iteration 31 / 150     best fitness : 0.1467455706758925
# ---------------------------------------
# Repeat 3 - Iteration 32 / 150     best fitness : 0.1467455706758925
# ---------------------------------------
# Repeat 3 - Iteration 33 / 150     best fitness : 0.13204946796218284
# ---------------------------------------
# Repeat 3 - Iteration 34 / 150     best fitness : 0.13204946796218284
# ---------------------------------------
# Repeat 3 - Iteration 35 / 150     best fitness : 0.13204946796218284
# ---------------------------------------
# Repeat 3 - Iteration 36 / 150     best fitness : 0.13204946796218284
# ---------------------------------------
# Repeat 3 - Iteration 37 / 150     best fitness : 0.12852659072394007
# ---------------------------------------
# Repeat 3 - Iteration 38 / 150     best fitness : 0.12852659072394007
# ---------------------------------------
# Repeat 3 - Iteration 39 / 150     best fitness : 0.12764966126175223
# ---------------------------------------
# Repeat 3 - Iteration 40 / 150     best fitness : 0.12764966126175223
# ---------------------------------------
# Repeat 3 - Iteration 41 / 150     best fitness : 0.12764966126175223
# ---------------------------------------
# Repeat 3 - Iteration 42 / 150     best fitness : 0.12722923632187297
# ---------------------------------------
# Repeat 3 - Iteration 43 / 150     best fitness : 0.12642063761265326
# ---------------------------------------
# Repeat 3 - Iteration 44 / 150     best fitness : 0.12642063761265326
# ---------------------------------------
# Repeat 3 - Iteration 45 / 150     best fitness : 0.12580283722265267
# ---------------------------------------
# Repeat 3 - Iteration 46 / 150     best fitness : 0.1254276225483286
# ---------------------------------------
# Repeat 3 - Iteration 47 / 150     best fitness : 0.1252665540880358
# ---------------------------------------
# Repeat 3 - Iteration 48 / 150     best fitness : 0.1230487148871399
# ---------------------------------------
# Repeat 3 - Iteration 49 / 150     best fitness : 0.1230487148871399
# ---------------------------------------
# Repeat 3 - Iteration 50 / 150     best fitness : 0.1230487148871399
# ---------------------------------------
# Repeat 3 - Iteration 51 / 150     best fitness : 0.1230487148871399
# ---------------------------------------
# Repeat 3 - Iteration 52 / 150     best fitness : 0.1230487148871399
# ---------------------------------------
# Repeat 3 - Iteration 53 / 150     best fitness : 0.12293860590471616
# ---------------------------------------
# Repeat 3 - Iteration 54 / 150     best fitness : 0.12293860590471616
# ---------------------------------------
# Repeat 3 - Iteration 55 / 150     best fitness : 0.12293860590471616
# ---------------------------------------
# Repeat 3 - Iteration 56 / 150     best fitness : 0.12108186503476381
# ---------------------------------------
# Repeat 3 - Iteration 57 / 150     best fitness : 0.12108186503476381
# ---------------------------------------
# Repeat 3 - Iteration 58 / 150     best fitness : 0.12108186503476381
# ---------------------------------------
# Repeat 3 - Iteration 59 / 150     best fitness : 0.12108186503476381
# ---------------------------------------
# Repeat 3 - Iteration 60 / 150     best fitness : 0.12108186503476381
# ---------------------------------------
# Repeat 3 - Iteration 61 / 150     best fitness : 0.11827126195674802
# ---------------------------------------
# Repeat 3 - Iteration 62 / 150     best fitness : 0.11827126195674802
# ---------------------------------------
# Repeat 3 - Iteration 63 / 150     best fitness : 0.11827126195674802
# ---------------------------------------
# Repeat 3 - Iteration 64 / 150     best fitness : 0.11827126195674802
# ---------------------------------------
# Repeat 3 - Iteration 65 / 150     best fitness : 0.1179833939224017
# ---------------------------------------
# Repeat 3 - Iteration 66 / 150     best fitness : 0.1179833939224017
# ---------------------------------------
# Repeat 3 - Iteration 67 / 150     best fitness : 0.1179833939224017
# ---------------------------------------
# Repeat 3 - Iteration 68 / 150     best fitness : 0.11792357416295497
# ---------------------------------------
# Repeat 3 - Iteration 69 / 150     best fitness : 0.11661087165388256
# ---------------------------------------
# Repeat 3 - Iteration 70 / 150     best fitness : 0.11418466344686856
# ---------------------------------------
# Repeat 3 - Iteration 71 / 150     best fitness : 0.11418466344686856
# ---------------------------------------
# Repeat 3 - Iteration 72 / 150     best fitness : 0.11407279695813001
# ---------------------------------------
# Repeat 3 - Iteration 73 / 150     best fitness : 0.11407279695813001
# ---------------------------------------
# Repeat 3 - Iteration 74 / 150     best fitness : 0.11179625156852689
# ---------------------------------------
# Repeat 3 - Iteration 75 / 150     best fitness : 0.11179625156852689
# ---------------------------------------
# Repeat 3 - Iteration 76 / 150     best fitness : 0.111313143702763
# ---------------------------------------
# Repeat 3 - Iteration 77 / 150     best fitness : 0.111313143702763
# ---------------------------------------
# Repeat 3 - Iteration 78 / 150     best fitness : 0.10979882262876053
# ---------------------------------------
# Repeat 3 - Iteration 79 / 150     best fitness : 0.10979882262876053
# ---------------------------------------
# Repeat 3 - Iteration 80 / 150     best fitness : 0.1093125011904503
# ---------------------------------------
# Repeat 3 - Iteration 81 / 150     best fitness : 0.1093125011904503
# ---------------------------------------
# Repeat 3 - Iteration 82 / 150     best fitness : 0.1093125011904503
# ---------------------------------------
# Repeat 3 - Iteration 83 / 150     best fitness : 0.1093125011904503
# ---------------------------------------
# Repeat 3 - Iteration 84 / 150     best fitness : 0.10930886669753637
# ---------------------------------------
# Repeat 3 - Iteration 85 / 150     best fitness : 0.10890363458815304
# ---------------------------------------
# Repeat 3 - Iteration 86 / 150     best fitness : 0.10778426359560479
# ---------------------------------------
# Repeat 3 - Iteration 87 / 150     best fitness : 0.10736555133752197
# ---------------------------------------
# Repeat 3 - Iteration 88 / 150     best fitness : 0.10654596878463332
# ---------------------------------------
# Repeat 3 - Iteration 89 / 150     best fitness : 0.10554850527244246
# ---------------------------------------
# Repeat 3 - Iteration 90 / 150     best fitness : 0.10554850527244246
# ---------------------------------------
# Repeat 3 - Iteration 91 / 150     best fitness : 0.10554850527244246
# ---------------------------------------
# Repeat 3 - Iteration 92 / 150     best fitness : 0.10554850527244246
# ---------------------------------------
# Repeat 3 - Iteration 93 / 150     best fitness : 0.10346799274645273
# ---------------------------------------
# Repeat 3 - Iteration 94 / 150     best fitness : 0.10257252785974053
# ---------------------------------------
# Repeat 3 - Iteration 95 / 150     best fitness : 0.10257252785974053
# ---------------------------------------
# Repeat 3 - Iteration 96 / 150     best fitness : 0.10257252785974053
# ---------------------------------------
# Repeat 3 - Iteration 97 / 150     best fitness : 0.10257252785974053
# ---------------------------------------
# Repeat 3 - Iteration 98 / 150     best fitness : 0.10257252785974053
# ---------------------------------------
# Repeat 3 - Iteration 99 / 150     best fitness : 0.10257252785974053
# ---------------------------------------
# Repeat 3 - Iteration 100 / 150     best fitness : 0.10137414959971651
# ---------------------------------------
# Repeat 3 - Iteration 101 / 150     best fitness : 0.100937688519903
# ---------------------------------------
# Repeat 3 - Iteration 102 / 150     best fitness : 0.100937688519903
# ---------------------------------------
# Repeat 3 - Iteration 103 / 150     best fitness : 0.09905884539391022
# ---------------------------------------
# Repeat 3 - Iteration 104 / 150     best fitness : 0.09905884539391022
# ---------------------------------------
# Repeat 3 - Iteration 105 / 150     best fitness : 0.09905884539391022
# ---------------------------------------
# Repeat 3 - Iteration 106 / 150     best fitness : 0.09905884539391022
# ---------------------------------------
# Repeat 3 - Iteration 107 / 150     best fitness : 0.09905884539391022
# ---------------------------------------
# Repeat 3 - Iteration 108 / 150     best fitness : 0.09892603048217793
# ---------------------------------------
# Repeat 3 - Iteration 109 / 150     best fitness : 0.09751500839244892
# ---------------------------------------
# Repeat 3 - Iteration 110 / 150     best fitness : 0.09734077839040071
# ---------------------------------------
# Repeat 3 - Iteration 111 / 150     best fitness : 0.09668390794251415
# ---------------------------------------
# Repeat 3 - Iteration 112 / 150     best fitness : 0.09668390794251415
# ---------------------------------------
# Repeat 3 - Iteration 113 / 150     best fitness : 0.09668390794251415
# ---------------------------------------
# Repeat 3 - Iteration 114 / 150     best fitness : 0.09650484637207045
# ---------------------------------------
# Repeat 3 - Iteration 115 / 150     best fitness : 0.09650484637207045
# ---------------------------------------
# Repeat 3 - Iteration 116 / 150     best fitness : 0.0964447742147588
# ---------------------------------------
# Repeat 3 - Iteration 117 / 150     best fitness : 0.09605605719367184
# ---------------------------------------
# Repeat 3 - Iteration 118 / 150     best fitness : 0.09605605719367184
# ---------------------------------------
# Repeat 3 - Iteration 119 / 150     best fitness : 0.09605605719367184
# ---------------------------------------
# Repeat 3 - Iteration 120 / 150     best fitness : 0.09596901823698765
# ---------------------------------------
# Repeat 3 - Iteration 121 / 150     best fitness : 0.09587231887963385
# ---------------------------------------
# Repeat 3 - Iteration 122 / 150     best fitness : 0.09525408373653718
# ---------------------------------------
# Repeat 3 - Iteration 123 / 150     best fitness : 0.09518120252528996
# ---------------------------------------
# Repeat 3 - Iteration 124 / 150     best fitness : 0.09518120252528996
# ---------------------------------------
# Repeat 3 - Iteration 125 / 150     best fitness : 0.09518120252528996
# ---------------------------------------
# Repeat 3 - Iteration 126 / 150     best fitness : 0.09518120252528996
# ---------------------------------------
# Repeat 3 - Iteration 127 / 150     best fitness : 0.09498962751395601
# ---------------------------------------
# Repeat 3 - Iteration 128 / 150     best fitness : 0.0946895838553499
# ---------------------------------------
# Repeat 3 - Iteration 129 / 150     best fitness : 0.0946895838553499
# ---------------------------------------
# Repeat 3 - Iteration 130 / 150     best fitness : 0.093867603879902
# ---------------------------------------
# Repeat 3 - Iteration 131 / 150     best fitness : 0.093867603879902
# ---------------------------------------
# Repeat 3 - Iteration 132 / 150     best fitness : 0.09386347044484751
# ---------------------------------------
# Repeat 3 - Iteration 133 / 150     best fitness : 0.09386347044484751
# ---------------------------------------
# Repeat 3 - Iteration 134 / 150     best fitness : 0.09345633173613324
# ---------------------------------------
# Repeat 3 - Iteration 135 / 150     best fitness : 0.09342231722974235
# ---------------------------------------
# Repeat 3 - Iteration 136 / 150     best fitness : 0.09329343619297702
# ---------------------------------------
# Repeat 3 - Iteration 137 / 150     best fitness : 0.0930077841504314
# ---------------------------------------
# Repeat 3 - Iteration 138 / 150     best fitness : 0.09279204388187434
# ---------------------------------------
# Repeat 3 - Iteration 139 / 150     best fitness : 0.09258066361875478
# ---------------------------------------
# Repeat 3 - Iteration 140 / 150     best fitness : 0.09233264592408497
# ---------------------------------------
# Repeat 3 - Iteration 141 / 150     best fitness : 0.09211118982159093
# ---------------------------------------
# Repeat 3 - Iteration 142 / 150     best fitness : 0.09197644817213259
# ---------------------------------------
# ...
# ---------------------------------------
# Repeat 5 - Iteration 5 / 150     best fitness : 0.17442026945267855
# ---------------------------------------
# Repeat 5 - Iteration 6 / 150     best fitness : 0.17442026945267855
# ---------------------------------------
# Repeat 5 - Iteration 7 / 150     best fitness : 0.17442026945267855
# ---------------------------------------
# Repeat 5 - Iteration 8 / 150     best fitness : 0.1714557544298166
# ---------------------------------------
# Repeat 5 - Iteration 9 / 150     best fitness : 0.1714557544298166
# ---------------------------------------
# Repeat 5 - Iteration 10 / 150     best fitness : 0.1714557544298166
# ---------------------------------------
# Repeat 5 - Iteration 11 / 150     best fitness : 0.1714557544298166
# ---------------------------------------
# Repeat 5 - Iteration 12 / 150     best fitness : 0.1714557544298166
# ---------------------------------------
# Repeat 5 - Iteration 13 / 150     best fitness : 0.15804872662383487
# ---------------------------------------
# Repeat 5 - Iteration 14 / 150     best fitness : 0.15804872662383487
# ---------------------------------------
# Repeat 5 - Iteration 15 / 150     best fitness : 0.14584398367354542
# ---------------------------------------
# Repeat 5 - Iteration 16 / 150     best fitness : 0.14584398367354542
# ---------------------------------------
# Repeat 5 - Iteration 17 / 150     best fitness : 0.1432183116707028
# ---------------------------------------
# Repeat 5 - Iteration 18 / 150     best fitness : 0.14283535688020027
# ---------------------------------------
# Repeat 5 - Iteration 19 / 150     best fitness : 0.14283535688020027
# ---------------------------------------
# Repeat 5 - Iteration 20 / 150     best fitness : 0.13500528212132584
# ---------------------------------------
# Repeat 5 - Iteration 21 / 150     best fitness : 0.13500528212132584
# ---------------------------------------
# Repeat 5 - Iteration 22 / 150     best fitness : 0.13500528212132584
# ---------------------------------------
# Repeat 5 - Iteration 23 / 150     best fitness : 0.13332020593744653
# ---------------------------------------
# Repeat 5 - Iteration 24 / 150     best fitness : 0.13332020593744653
# ---------------------------------------
# Repeat 5 - Iteration 25 / 150     best fitness : 0.129741431359933
# ---------------------------------------
# Repeat 5 - Iteration 26 / 150     best fitness : 0.129741431359933
# ---------------------------------------
# Repeat 5 - Iteration 27 / 150     best fitness : 0.12826787444891602
# ---------------------------------------
# Repeat 5 - Iteration 28 / 150     best fitness : 0.12568527358579276
# ---------------------------------------
# Repeat 5 - Iteration 29 / 150     best fitness : 0.12568527358579276
# ---------------------------------------
# Repeat 5 - Iteration 30 / 150     best fitness : 0.12531560718566181
# ---------------------------------------
# Repeat 5 - Iteration 31 / 150     best fitness : 0.12531560718566181
# ---------------------------------------
# Repeat 5 - Iteration 32 / 150     best fitness : 0.12531560718566181
# ---------------------------------------
# Repeat 5 - Iteration 33 / 150     best fitness : 0.12531560718566181
# ---------------------------------------
# Repeat 5 - Iteration 34 / 150     best fitness : 0.12465198223988581
# ---------------------------------------
# Repeat 5 - Iteration 35 / 150     best fitness : 0.12465198223988581
# ---------------------------------------
# Repeat 5 - Iteration 36 / 150     best fitness : 0.12465198223988581
# ---------------------------------------
# Repeat 5 - Iteration 37 / 150     best fitness : 0.12465198223988581
# ---------------------------------------
# Repeat 5 - Iteration 38 / 150     best fitness : 0.12465198223988581
# ---------------------------------------
# Repeat 5 - Iteration 39 / 150     best fitness : 0.12438826271592074
# ---------------------------------------
# Repeat 5 - Iteration 40 / 150     best fitness : 0.1235157799049896
# ---------------------------------------
# Repeat 5 - Iteration 41 / 150     best fitness : 0.1235157799049896
# ---------------------------------------
# Repeat 5 - Iteration 42 / 150     best fitness : 0.12300660842742661
# ---------------------------------------
# Repeat 5 - Iteration 43 / 150     best fitness : 0.12300660842742661
# ---------------------------------------
# Repeat 5 - Iteration 44 / 150     best fitness : 0.12286886327210467
# ---------------------------------------
# Repeat 5 - Iteration 45 / 150     best fitness : 0.12171516554448035
# ---------------------------------------
# Repeat 5 - Iteration 46 / 150     best fitness : 0.11748933588119673
# ---------------------------------------
# Repeat 5 - Iteration 47 / 150     best fitness : 0.11748933588119673
# ---------------------------------------
# Repeat 5 - Iteration 48 / 150     best fitness : 0.11748933588119673
# ---------------------------------------
# Repeat 5 - Iteration 49 / 150     best fitness : 0.11448514111149362
# ---------------------------------------
# Repeat 5 - Iteration 50 / 150     best fitness : 0.11448514111149362
# ---------------------------------------
# Repeat 5 - Iteration 51 / 150     best fitness : 0.11448514111149362
# ---------------------------------------
# Repeat 5 - Iteration 52 / 150     best fitness : 0.11443763330072626
# ---------------------------------------
# Repeat 5 - Iteration 53 / 150     best fitness : 0.1139711333564843
# ---------------------------------------
# Repeat 5 - Iteration 54 / 150     best fitness : 0.1138996092655844
# ---------------------------------------
# Repeat 5 - Iteration 55 / 150     best fitness : 0.11328251259090803
# ---------------------------------------
# Repeat 5 - Iteration 56 / 150     best fitness : 0.11317173535261611
# ---------------------------------------
# Repeat 5 - Iteration 57 / 150     best fitness : 0.11317173535261611
# ---------------------------------------
# Repeat 5 - Iteration 58 / 150     best fitness : 0.11190630214042964
# ---------------------------------------
# Repeat 5 - Iteration 59 / 150     best fitness : 0.11190630214042964
# ---------------------------------------
# Repeat 5 - Iteration 60 / 150     best fitness : 0.11190630214042964
# ---------------------------------------
# Repeat 5 - Iteration 61 / 150     best fitness : 0.11190630214042964
# ---------------------------------------
# Repeat 5 - Iteration 62 / 150     best fitness : 0.11190630214042964
# ---------------------------------------
# Repeat 5 - Iteration 63 / 150     best fitness : 0.11187480977810067
# ---------------------------------------
# Repeat 5 - Iteration 64 / 150     best fitness : 0.11187480977810067
# ---------------------------------------
# Repeat 5 - Iteration 65 / 150     best fitness : 0.11015289235717146
# ---------------------------------------
# Repeat 5 - Iteration 66 / 150     best fitness : 0.11015289235717146
# ---------------------------------------
# Repeat 5 - Iteration 67 / 150     best fitness : 0.11015289235717146
# ---------------------------------------
# Repeat 5 - Iteration 68 / 150     best fitness : 0.11015289235717146
# ---------------------------------------
# Repeat 5 - Iteration 69 / 150     best fitness : 0.11005868299992137
# ---------------------------------------
# Repeat 5 - Iteration 70 / 150     best fitness : 0.11005868299992137
# ---------------------------------------
# Repeat 5 - Iteration 71 / 150     best fitness : 0.11005647167930112
# ---------------------------------------
# Repeat 5 - Iteration 72 / 150     best fitness : 0.10928184564205215
# ---------------------------------------
# Repeat 5 - Iteration 73 / 150     best fitness : 0.10928184564205215
# ---------------------------------------
# Repeat 5 - Iteration 74 / 150     best fitness : 0.10928184564205215
# ---------------------------------------
# Repeat 5 - Iteration 75 / 150     best fitness : 0.10928184564205215
# ---------------------------------------
# Repeat 5 - Iteration 76 / 150     best fitness : 0.10928184564205215
# ---------------------------------------
# Repeat 5 - Iteration 77 / 150     best fitness : 0.10928184564205215
# ---------------------------------------
# Repeat 5 - Iteration 78 / 150     best fitness : 0.10928184564205215
# ---------------------------------------
# Repeat 5 - Iteration 79 / 150     best fitness : 0.10928184564205215
# ---------------------------------------
# Repeat 5 - Iteration 80 / 150     best fitness : 0.10928184564205215
# ---------------------------------------
# Repeat 5 - Iteration 81 / 150     best fitness : 0.10928184564205215
# ---------------------------------------
# Repeat 5 - Iteration 82 / 150     best fitness : 0.10928184564205215
# ---------------------------------------
# Repeat 5 - Iteration 83 / 150     best fitness : 0.10898726432808728
# ---------------------------------------
# Repeat 5 - Iteration 84 / 150     best fitness : 0.10873482434741637
# ---------------------------------------
# Repeat 5 - Iteration 85 / 150     best fitness : 0.10873482434741637
# ---------------------------------------
# Repeat 5 - Iteration 86 / 150     best fitness : 0.10873482434741637
# ---------------------------------------
# Repeat 5 - Iteration 87 / 150     best fitness : 0.10864275512296248
# ---------------------------------------
# Repeat 5 - Iteration 88 / 150     best fitness : 0.10864275512296248
# ---------------------------------------
# Repeat 5 - Iteration 89 / 150     best fitness : 0.1081599053660623
# ---------------------------------------
# Repeat 5 - Iteration 90 / 150     best fitness : 0.10705787133087505
# ---------------------------------------
# Repeat 5 - Iteration 91 / 150     best fitness : 0.10705787133087505
# ---------------------------------------
# Repeat 5 - Iteration 92 / 150     best fitness : 0.10700945983453079
# ---------------------------------------
# Repeat 5 - Iteration 93 / 150     best fitness : 0.10677974111833301
# ---------------------------------------
# Repeat 5 - Iteration 94 / 150     best fitness : 0.10677974111833301
# ---------------------------------------
# Repeat 5 - Iteration 95 / 150     best fitness : 0.10629307724910397
# ---------------------------------------
# Repeat 5 - Iteration 96 / 150     best fitness : 0.10608297529022508
# ---------------------------------------
# Repeat 5 - Iteration 97 / 150     best fitness : 0.10604677617494512
# ---------------------------------------
# Repeat 5 - Iteration 98 / 150     best fitness : 0.10595417816033363
# ---------------------------------------
# Repeat 5 - Iteration 99 / 150     best fitness : 0.10539011003625562
# ---------------------------------------
# Repeat 5 - Iteration 100 / 150     best fitness : 0.10388921235004883
# ---------------------------------------
# Repeat 5 - Iteration 101 / 150     best fitness : 0.10388921235004883
# ---------------------------------------
# Repeat 5 - Iteration 102 / 150     best fitness : 0.10388921235004883
# ---------------------------------------
# Repeat 5 - Iteration 103 / 150     best fitness : 0.10357903150096287
# ---------------------------------------
# Repeat 5 - Iteration 104 / 150     best fitness : 0.10318207764134664
# ---------------------------------------
# Repeat 5 - Iteration 105 / 150     best fitness : 0.10318207764134664
# ---------------------------------------
# Repeat 5 - Iteration 106 / 150     best fitness : 0.10260437552024848
# ---------------------------------------
# Repeat 5 - Iteration 107 / 150     best fitness : 0.1025639066905696
# ---------------------------------------
# Repeat 5 - Iteration 108 / 150     best fitness : 0.1025639066905696
# ---------------------------------------
# Repeat 5 - Iteration 109 / 150     best fitness : 0.1025639066905696
# ---------------------------------------
# Repeat 5 - Iteration 110 / 150     best fitness : 0.10246163427152999
# ---------------------------------------
# Repeat 5 - Iteration 111 / 150     best fitness : 0.1019078748400418
# ---------------------------------------
# Repeat 5 - Iteration 112 / 150     best fitness : 0.1019078748400418
# ---------------------------------------
# Repeat 5 - Iteration 113 / 150     best fitness : 0.10156948174766912
# ---------------------------------------
# Repeat 5 - Iteration 114 / 150     best fitness : 0.10141320718794487
# ---------------------------------------
# Repeat 5 - Iteration 115 / 150     best fitness : 0.10141320718794487
# ---------------------------------------
# Repeat 5 - Iteration 116 / 150     best fitness : 0.10141320718794487
# ---------------------------------------
# Repeat 5 - Iteration 117 / 150     best fitness : 0.10099454966131102
# ---------------------------------------
# Repeat 5 - Iteration 118 / 150     best fitness : 0.10099454966131102
# ---------------------------------------
# Repeat 5 - Iteration 119 / 150     best fitness : 0.10089491846327042
# ---------------------------------------
# Repeat 5 - Iteration 120 / 150     best fitness : 0.1006482140606301
# ---------------------------------------
# Repeat 5 - Iteration 121 / 150     best fitness : 0.09911741938664392
# ---------------------------------------
# Repeat 5 - Iteration 122 / 150     best fitness : 0.09885316693239585
# ---------------------------------------
# Repeat 5 - Iteration 123 / 150     best fitness : 0.09885316693239585
# ---------------------------------------
# Repeat 5 - Iteration 124 / 150     best fitness : 0.09885316693239585
# ---------------------------------------
# Repeat 5 - Iteration 125 / 150     best fitness : 0.09885316693239585
# ---------------------------------------
# Repeat 5 - Iteration 126 / 150     best fitness : 0.09873860796728647
# ---------------------------------------
# Repeat 5 - Iteration 127 / 150     best fitness : 0.09873860796728647
# ---------------------------------------
# Repeat 5 - Iteration 128 / 150     best fitness : 0.09838932114324103
# ---------------------------------------
# Repeat 5 - Iteration 129 / 150     best fitness : 0.09784172564799434
# ---------------------------------------
# Repeat 5 - Iteration 130 / 150     best fitness : 0.09784172564799434
# ---------------------------------------
# Repeat 5 - Iteration 131 / 150     best fitness : 0.09784172564799434
# ---------------------------------------
# Repeat 5 - Iteration 132 / 150     best fitness : 0.09758911773075529
# ---------------------------------------
# Repeat 5 - Iteration 133 / 150     best fitness : 0.09711456227813603
# ---------------------------------------
# Repeat 5 - Iteration 134 / 150     best fitness : 0.09711456227813603
# ---------------------------------------
# Repeat 5 - Iteration 135 / 150     best fitness : 0.09711456227813603
# ---------------------------------------
# Repeat 5 - Iteration 136 / 150     best fitness : 0.09702916274753118
# ---------------------------------------
# Repeat 5 - Iteration 137 / 150     best fitness : 0.09694047267502973
# ---------------------------------------
# Repeat 5 - Iteration 138 / 150     best fitness : 0.09694047267502973
# ---------------------------------------
# Repeat 5 - Iteration 139 / 150     best fitness : 0.09687335731345476
# ---------------------------------------
# Repeat 5 - Iteration 140 / 150     best fitness : 0.09658225411963113
# ---------------------------------------
# Repeat 5 - Iteration 141 / 150     best fitness : 0.09658225411963113
# ---------------------------------------
# Repeat 5 - Iteration 142 / 150     best fitness : 0.09635010022127401
# ---------------------------------------
# Repeat 5 - Iteration 143 / 150     best fitness : 0.09635010022127401
# ---------------------------------------
# Repeat 5 - Iteration 144 / 150     best fitness : 0.09619435879735407
# ---------------------------------------
# Repeat 5 - Iteration 145 / 150     best fitness : 0.09619435879735407
# ---------------------------------------
# Repeat 5 - Iteration 146 / 150     best fitness : 0.09615452352831784
# ---------------------------------------
# Repeat 5 - Iteration 147 / 150     best fitness : 0.0961102010884332
# ---------------------------------------
# Repeat 5 - Iteration 148 / 150     best fitness : 0.09573967049498996
# ---------------------------------------
# Repeat 5 - Iteration 149 / 150     best fitness : 0.09573967049498996
# ---------------------------------------
# Mean fitness over all repeats: 0.0892807331209827
# Standard deviation of fitness over all repeats: 0.005224896650913055

# %%
# Evaluate and plot results for Iris dataset.
best_params = results_iris.best_individual  # Get the best parameters.
iris_classifier.set_params_from_vector(best_params)  # Set the MLP parameters to the best found by MFO.

plot_learning_curves(results_iris.convergence_curve)  # Plot convergence curves for Iris dataset.

train_output = iris_classifier.forward_pass(train_X_iris)  # Predict on training data.

visualize_confusion_matrix(train_Y_iris, train_output, unique_iris, 'train', normalize=False)  # Plot confusion matrix for training data.
test_output = iris_classifier.forward_pass(test_X_iris)  # Predict on test data.

visualize_confusion_matrix(test_Y_iris, test_output, unique_iris, 'test', normalize=False)  # Plot confusion matrix for test data.
# Out:
# Confusion Matrix, without normalization
# Confusion Matrix, without normalization

# %% [markdown]
# # Breast cancer

# %%
results_breast = MothFlameOptimizer(objective_function=objective_function, dimensions=breast_classifier.trainable_params, 
                                    train_input=train_X_breast, train_target=train_Y_breast, 
                                    neural_net_func=breast_classifier, num_moths=15, max_iterations=50 , repeat = 5)
# Out:
# Repeat 1 - Iteration 1 / 50     best fitness : 0.08687109668820313
# ---------------------------------------
# Repeat 1 - Iteration 2 / 50     best fitness : 0.08687109668820313
# ---------------------------------------
# Repeat 1 - Iteration 3 / 50     best fitness : 0.08687109668820313
# ---------------------------------------
# Repeat 1 - Iteration 4 / 50     best fitness : 0.08687109668820313
# ---------------------------------------
# Repeat 1 - Iteration 5 / 50     best fitness : 0.05769405001931462
# ---------------------------------------
# Repeat 1 - Iteration 6 / 50     best fitness : 0.05769405001931462
# ---------------------------------------
# Repeat 1 - Iteration 7 / 50     best fitness : 0.05769405001931462
# ---------------------------------------
# Repeat 1 - Iteration 8 / 50     best fitness : 0.05711248845119641
# ---------------------------------------
# Repeat 1 - Iteration 9 / 50     best fitness : 0.05711248845119641
# ---------------------------------------
# Repeat 1 - Iteration 10 / 50     best fitness : 0.056331844555959826
# ---------------------------------------
# Repeat 1 - Iteration 11 / 50     best fitness : 0.040136053667454964
# ---------------------------------------
# Repeat 1 - Iteration 12 / 50     best fitness : 0.040136053667454964
# ---------------------------------------
# Repeat 1 - Iteration 13 / 50     best fitness : 0.040136053667454964
# ---------------------------------------
# Repeat 1 - Iteration 14 / 50     best fitness : 0.040136053667454964
# ---------------------------------------
# Repeat 1 - Iteration 15 / 50     best fitness : 0.040136053667454964
# ---------------------------------------
# Repeat 1 - Iteration 16 / 50     best fitness : 0.040136053667454964
# ---------------------------------------
# Repeat 1 - Iteration 17 / 50     best fitness : 0.03822636843978931
# ---------------------------------------
# Repeat 1 - Iteration 18 / 50     best fitness : 0.03226061477116904
# ---------------------------------------
# Repeat 1 - Iteration 19 / 50     best fitness : 0.03220227588932863
# ---------------------------------------
# Repeat 1 - Iteration 20 / 50     best fitness : 0.03220227588932863
# ---------------------------------------
# Repeat 1 - Iteration 21 / 50     best fitness : 0.029477905149728423
# ---------------------------------------
# Repeat 1 - Iteration 22 / 50     best fitness : 0.029477905149728423
# ---------------------------------------
# Repeat 1 - Iteration 23 / 50     best fitness : 0.025317300416754913
# Repeat 2 - Iteration 8 / 50     best fitness : 0.030650101392543632
# ---------------------------------------
# Repeat 2 - Iteration 9 / 50     best fitness : 0.030650101392543632
# ---------------------------------------
# Repeat 2 - Iteration 10 / 50     best fitness : 0.030650101392543632
# ---------------------------------------
# Repeat 2 - Iteration 11 / 50     best fitness : 0.030650101392543632
# ---------------------------------------
# Repeat 2 - Iteration 12 / 50     best fitness : 0.030650101392543632
# ---------------------------------------
# Repeat 2 - Iteration 13 / 50     best fitness : 0.02905851165159592
# ---------------------------------------
# Repeat 2 - Iteration 14 / 50     best fitness : 0.02905851165159592
# ---------------------------------------
# Repeat 2 - Iteration 15 / 50     best fitness : 0.027582791691253147
# ---------------------------------------
# Repeat 2 - Iteration 16 / 50     best fitness : 0.026313535549263405
# ---------------------------------------
# Repeat 2 - Iteration 17 / 50     best fitness : 0.026008004642541188
# ---------------------------------------
# Repeat 2 - Iteration 18 / 50     best fitness : 0.025581677664273654
# ---------------------------------------
# Repeat 2 - Iteration 19 / 50     best fitness : 0.025168917555127297
# ---------------------------------------
# Repeat 2 - Iteration 20 / 50     best fitness : 0.025168917555127297
# ---------------------------------------
# Repeat 2 - Iteration 21 / 50     best fitness : 0.022614694500855417
# ---------------------------------------
# Repeat 2 - Iteration 22 / 50     best fitness : 0.022614694500855417
# ---------------------------------------
# Repeat 2 - Iteration 23 / 50     best fitness : 0.02261006914038896
# ---------------------------------------
# Repeat 2 - Iteration 24 / 50     best fitness : 0.02261006914038896
# ---------------------------------------
# Repeat 2 - Iteration 25 / 50     best fitness : 0.02261006914038896
# ---------------------------------------
# Repeat 2 - Iteration 26 / 50     best fitness : 0.021475281109103114
# ---------------------------------------
# Repeat 2 - Iteration 27 / 50     best fitness : 0.021475281109103114
# ---------------------------------------
# Repeat 2 - Iteration 28 / 50     best fitness : 0.021475281109103114
# ---------------------------------------
# Repeat 2 - Iteration 29 / 50     best fitness : 0.021475281109103114
# ---------------------------------------
# Repeat 2 - Iteration 30 / 50     best fitness : 0.021036257455933106
# ---------------------------------------
# Repeat 2 - Iteration 31 / 50     best fitness : 0.020940225525787164
# ---------------------------------------
# Repeat 2 - Iteration 32 / 50     best fitness : 0.02069684991296035
# ---------------------------------------
# Repeat 2 - Iteration 33 / 50     best fitness : 0.02069684991296035
# ---------------------------------------
# Repeat 2 - Iteration 34 / 50     best fitness : 0.020138048488786402
# ---------------------------------------
# Repeat 2 - Iteration 35 / 50     best fitness : 0.020138048488786402
# ---------------------------------------
# Repeat 2 - Iteration 36 / 50     best fitness : 0.019979711229794146
# ---------------------------------------
# Repeat 2 - Iteration 37 / 50     best fitness : 0.01949053070986608
# ---------------------------------------
# Repeat 2 - Iteration 38 / 50     best fitness : 0.01949053070986608
# ---------------------------------------
# Repeat 2 - Iteration 39 / 50     best fitness : 0.019018516403300028
# ---------------------------------------
# Repeat 2 - Iteration 40 / 50     best fitness : 0.019018516403300028
# ---------------------------------------
# Repeat 2 - Iteration 41 / 50     best fitness : 0.019018516403300028
# ---------------------------------------
# Repeat 2 - Iteration 42 / 50     best fitness : 0.01883898607440638
# ---------------------------------------
# Repeat 2 - Iteration 43 / 50     best fitness : 0.017785045875553986
# ---------------------------------------
# Repeat 2 - Iteration 44 / 50     best fitness : 0.017785045875553986
# ---------------------------------------
# Repeat 2 - Iteration 45 / 50     best fitness : 0.017785045875553986
# ---------------------------------------
# Repeat 2 - Iteration 46 / 50     best fitness : 0.017774241922087926
# ---------------------------------------
# Repeat 2 - Iteration 47 / 50     best fitness : 0.017618598530937134
# ---------------------------------------
# Repeat 2 - Iteration 48 / 50     best fitness : 0.01725763838884046
# ---------------------------------------
# Repeat 2 - Iteration 49 / 50     best fitness : 0.01725763838884046
# ---------------------------------------
# Repeat 3 - Iteration 1 / 50     best fitness : 0.148557829989033
# ---------------------------------------
# Repeat 3 - Iteration 2 / 50     best fitness : 0.11678077503243034
# ---------------------------------------
# Repeat 3 - Iteration 3 / 50     best fitness : 0.0619882264126064
# ---------------------------------------
# Repeat 3 - Iteration 4 / 50     best fitness : 0.0619882264126064
# ---------------------------------------
# Repeat 3 - Iteration 5 / 50     best fitness : 0.0619882264126064
# ---------------------------------------
# Repeat 3 - Iteration 6 / 50     best fitness : 0.0619882264126064
# ---------------------------------------
# Repeat 3 - Iteration 7 / 50     best fitness : 0.0619882264126064
# ---------------------------------------
# Repeat 3 - Iteration 8 / 50     best fitness : 0.035954974036733575
# ---------------------------------------
# Repeat 3 - Iteration 9 / 50     best fitness : 0.035954974036733575
# ---------------------------------------
# Repeat 3 - Iteration 10 / 50     best fitness : 0.035954974036733575
# ---------------------------------------
# Repeat 3 - Iteration 11 / 50     best fitness : 0.03266546377063349
# ---------------------------------------
# Repeat 3 - Iteration 12 / 50     best fitness : 0.03266546377063349
# ---------------------------------------
# Repeat 3 - Iteration 13 / 50     best fitness : 0.03266546377063349
# ---------------------------------------
# Repeat 3 - Iteration 14 / 50     best fitness : 0.032013876664681924
# ---------------------------------------
# Repeat 3 - Iteration 15 / 50     best fitness : 0.030708792124426502
# ---------------------------------------
# Repeat 3 - Iteration 16 / 50     best fitness : 0.030708792124426502
# ---------------------------------------
# Repeat 3 - Iteration 17 / 50     best fitness : 0.027023177551282525
# ---------------------------------------
# Repeat 3 - Iteration 18 / 50     best fitness : 0.027023177551282525
# ---------------------------------------
# Repeat 3 - Iteration 19 / 50     best fitness : 0.027023177551282525
# ---------------------------------------
# Repeat 3 - Iteration 20 / 50     best fitness : 0.022528216171618796
# ---------------------------------------
# Repeat 3 - Iteration 21 / 50     best fitness : 0.022528216171618796
# ---------------------------------------
# Repeat 3 - Iteration 22 / 50     best fitness : 0.022528216171618796
# ---------------------------------------
# Repeat 3 - Iteration 23 / 50     best fitness : 0.022528216171618796
# ---------------------------------------
# Repeat 3 - Iteration 24 / 50     best fitness : 0.02165012373054483
# ---------------------------------------
# Repeat 3 - Iteration 25 / 50     best fitness : 0.020184987226486283
# ---------------------------------------
# Repeat 3 - Iteration 26 / 50     best fitness : 0.020184987226486283
# Repeat 4 - Iteration 45 / 50     best fitness : 0.018817506769688106
# ---------------------------------------
# Repeat 4 - Iteration 46 / 50     best fitness : 0.018817506769688106
# ---------------------------------------
# Repeat 4 - Iteration 47 / 50     best fitness : 0.018134608082747777
# ---------------------------------------
# Repeat 4 - Iteration 48 / 50     best fitness : 0.018134608082747777
# ---------------------------------------
# Repeat 4 - Iteration 49 / 50     best fitness : 0.018123260100273035
# ---------------------------------------
# Repeat 5 - Iteration 1 / 50     best fitness : 0.2502233251962072
# ---------------------------------------
# Repeat 5 - Iteration 2 / 50     best fitness : 0.18498581332336475
# ---------------------------------------
# Repeat 5 - Iteration 3 / 50     best fitness : 0.07437706974962259
# ---------------------------------------
# Repeat 5 - Iteration 4 / 50     best fitness : 0.07437706974962259
# ---------------------------------------
# Repeat 5 - Iteration 5 / 50     best fitness : 0.07092248979067219
# ---------------------------------------
# Repeat 5 - Iteration 6 / 50     best fitness : 0.07092248979067219
# ---------------------------------------
# Repeat 5 - Iteration 7 / 50     best fitness : 0.07092248979067219
# ---------------------------------------
# Repeat 5 - Iteration 8 / 50     best fitness : 0.07092248979067219
# ---------------------------------------
# Repeat 5 - Iteration 9 / 50     best fitness : 0.06683512522898646
# ---------------------------------------
# Repeat 5 - Iteration 10 / 50     best fitness : 0.031223938852726882
# ---------------------------------------
# Repeat 5 - Iteration 11 / 50     best fitness : 0.031223938852726882
# ---------------------------------------
# Repeat 5 - Iteration 12 / 50     best fitness : 0.031223938852726882
# ---------------------------------------
# Repeat 5 - Iteration 13 / 50     best fitness : 0.031223938852726882
# ---------------------------------------
# Repeat 5 - Iteration 14 / 50     best fitness : 0.031223938852726882
# ---------------------------------------
# Repeat 5 - Iteration 15 / 50     best fitness : 0.028651091531119867
# ---------------------------------------
# Repeat 5 - Iteration 16 / 50     best fitness : 0.028651091531119867
# ---------------------------------------
# Repeat 5 - Iteration 17 / 50     best fitness : 0.025797134321068668
# ---------------------------------------
# Repeat 5 - Iteration 18 / 50     best fitness : 0.025797134321068668
# ---------------------------------------
# Repeat 5 - Iteration 19 / 50     best fitness : 0.025797134321068668
# ---------------------------------------
# Repeat 5 - Iteration 20 / 50     best fitness : 0.02266392940199902
# ---------------------------------------
# Repeat 5 - Iteration 21 / 50     best fitness : 0.02266392940199902
# ---------------------------------------
# Repeat 5 - Iteration 22 / 50     best fitness : 0.02266392940199902
# ---------------------------------------
# Repeat 5 - Iteration 23 / 50     best fitness : 0.02266392940199902
# ---------------------------------------
# Repeat 5 - Iteration 24 / 50     best fitness : 0.02258329202021531
# ---------------------------------------
# Repeat 5 - Iteration 25 / 50     best fitness : 0.02258329202021531
# ---------------------------------------
# Repeat 5 - Iteration 26 / 50     best fitness : 0.022271507579732466
# ---------------------------------------
# Repeat 5 - Iteration 27 / 50     best fitness : 0.021955166167638616
# ---------------------------------------
# Repeat 5 - Iteration 28 / 50     best fitness : 0.021955166167638616
# ---------------------------------------
# Repeat 5 - Iteration 29 / 50     best fitness : 0.02115487133829448
# ---------------------------------------
# Repeat 5 - Iteration 30 / 50     best fitness : 0.02115487133829448
# ---------------------------------------
# Repeat 5 - Iteration 31 / 50     best fitness : 0.020785384193559606
# ---------------------------------------
# Repeat 5 - Iteration 32 / 50     best fitness : 0.020292862631413246
# ---------------------------------------
# Repeat 5 - Iteration 33 / 50     best fitness : 0.020292862631413246
# ---------------------------------------
# Repeat 5 - Iteration 34 / 50     best fitness : 0.01954423633017809
# ---------------------------------------
# Repeat 5 - Iteration 35 / 50     best fitness : 0.01954423633017809
# ---------------------------------------
# Repeat 5 - Iteration 36 / 50     best fitness : 0.01954423633017809
# ---------------------------------------
# Repeat 5 - Iteration 37 / 50     best fitness : 0.019262850947960816
# ---------------------------------------
# Repeat 5 - Iteration 38 / 50     best fitness : 0.019245622230720048
# ---------------------------------------
# Repeat 5 - Iteration 39 / 50     best fitness : 0.019232360215292663
# ---------------------------------------
# Repeat 5 - Iteration 40 / 50     best fitness : 0.018778850315274605
# ---------------------------------------
# Repeat 5 - Iteration 41 / 50     best fitness : 0.018778850315274605
# ---------------------------------------
# Repeat 5 - Iteration 42 / 50     best fitness : 0.018296221693327078
# ---------------------------------------
# Repeat 5 - Iteration 43 / 50     best fitness : 0.018296221693327078
# ---------------------------------------
# Repeat 5 - Iteration 44 / 50     best fitness : 0.018296221693327078
# ---------------------------------------
# Repeat 5 - Iteration 45 / 50     best fitness : 0.01817520060591102
# ---------------------------------------
# Repeat 5 - Iteration 46 / 50     best fitness : 0.018136162224218988
# ---------------------------------------
# Repeat 5 - Iteration 47 / 50     best fitness : 0.018128907153758974
# ---------------------------------------
# Repeat 5 - Iteration 48 / 50     best fitness : 0.017781773572123395
# ---------------------------------------
# Repeat 5 - Iteration 49 / 50     best fitness : 0.01777661240195216
# ---------------------------------------
# Mean fitness over all repeats: 0.017768656019673378
# Standard deviation of fitness over all repeats: 0.00041516810525910286

# %%
# Evaluate and plot results for Breast Cancer dataset.
best_params = results_breast.best_individual  # Get the best parameters.
breast_classifier.set_params_from_vector(best_params)  # Set the MLP parameters to the best found by MFO.
train_output = breast_classifier.forward_pass(train_X_breast)  # Predict on training data.
train_output = np.where(train_output < 0.5, 0, 1)  # Convert predictions to binary labels.
train_output, _ = encode_one_hot(train_output)  # One-hot encode the predictions.
train_target, _ = encode_one_hot(train_Y_breast)  # One-hot encode the true labels.
visualize_confusion_matrix(train_target, train_output, unique_breasts, 'train', normalize=False)  # Plot confusion matrix for training data.

test_output = breast_classifier.forward_pass(test_X_breast)  # Predict on test data.
test_output = np.where(test_output < 0.5, 0, 1)  # Convert predictions to binary labels.
test_output, _ = encode_one_hot(test_output)  # One-hot encode the predictions.
test_target, _ = encode_one_hot(test_Y_breast)  # One-hot encode the true labels.
visualize_confusion_matrix(test_target, test_output, unique_breasts, 'test', normalize=False)  # Plot confusion matrix for test data.

plot_learning_curves(results_breast.convergence_curve)  # Plot convergence curves for Breast Cancer dataset.
# Out:
# Confusion Matrix, without normalization
# Confusion Matrix, without normalization
